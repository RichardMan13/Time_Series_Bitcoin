# %%
import pandas as pd
import numpy as np

from scipy.stats import pearsonr
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

from statsmodels.tsa.arima_model import ARIMA

import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline 

import warnings
warnings.simplefilter('ignore')

# %%
pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 100)

# %% [markdown]
# #### read csv files from kaggle

# %%
df_gemini_price_d = pd.read_csv('datasets/kaggle/BTCUSD_day.csv')
df_gemini_price_1h = pd.read_csv('datasets/kaggle/BTCUSD_1hr.csv')

# %% [markdown]
# #### convert columns to datetime

# %%
df_gemini_price_d['Date'] = pd.to_datetime(df_gemini_price_d['Date'])
df_gemini_price_1h['Date'] = pd.to_datetime(df_gemini_price_1h['Date'])

# %% [markdown]
# #### verify the range of datetime in dataframes

# %%
print('------------', 'df_gemini_price_d', '------------')
print(df_gemini_price_d['Date'].max())
print(df_gemini_price_d['Date'].min())
print('------------', 'df_gemini_price_1h', '------------')
print(df_gemini_price_1h['Date'].max())
print(df_gemini_price_1h['Date'].min())
# Out:
# ------------ df_gemini_price_d ------------
# 2020-04-09 00:00:00
# 2015-10-08 00:00:00
# ------------ df_gemini_price_1h ------------
# 2020-04-09 00:00:00
# 2015-10-08 13:00:00

# %% [markdown]
# #### verify the numbers of lines in dataframes

# %%
print('------------', 'df_coinmarket_price_d', '------------')
print(df_gemini_price_d.shape[0])
print('------------', 'df_coinmarket_price_1h', '------------')
print(df_gemini_price_1h.shape[0])
# Out:
# ------------ df_coinmarket_price_d ------------
# 1646
# ------------ df_coinmarket_price_1h ------------
# 39468

# %%
class ARForecast(object):
    
    def __init__(self, df, percentage_train_size, periodicity):
        
        self.df = df
        self.percentage_train_size = percentage_train_size
        self.periodicity = periodicity 
        
    def perform(self):
        
        best_params, train_size, y_train_predict = self.grid_search_model()
                
        array_pred = np.array([])
        
        date_test = self.df[train_size:].index
        
        for current_datetime in date_test:

            pred = self.prediction(best_params = best_params, current_datetime = current_datetime)
            array_pred = np.append(array_pred, pred)
            print('current_datetime ->', current_datetime)
            print('pred ->', pred)
            print('---')
#         print('---')

        date_train = self.df[:train_size].index
#         date_train = y_train_predict.index
        y_train = self.df[:train_size]['Close'].values
        
        date_test = self.df[train_size:].index
        y_test = self.df[train_size:]['Close'].values
        
        data_train = {
          'date_train': date_train,
          'y_train': y_train,
#           'y_train_predict': y_train_predict.values
        }

        data_test = {
            'date_test': date_test,
            'y_test': y_test,
            'y_test_predict': array_pred
        }

        df_train = pd.DataFrame(data_train)
        df_test = pd.DataFrame(data_test)

        mae, mape, mse, rmse, rmspe, r2, pearson = self.perform_metrics(df_test['y_test'],
                                                                        df_test['y_test_predict'])
        print('mae', mae,
              'mape', mape,
              'mse', mse,
              'rmse', rmse,
              'rmspe', rmspe,
              'r2', r2,
              'pearson', pearson)

        
        return df_train, df_test
        
    def perform_metrics(self, y_truth, y_forecasted): 

        mae = round(mean_absolute_error(y_truth, y_forecasted) ,4)
        mape = round(np.mean(np.abs((y_truth - y_forecasted) / y_truth)) * 100, 4)
        mse = round(mean_squared_error(y_truth, y_forecasted), 4)
        rmse = round(mse**(0.5), 4)
        rmspe = round((np.sqrt(np.mean(np.square((y_truth - y_forecasted) / y_truth)))) * 100, 4)
        r2 = round(r2_score(y_truth, y_forecasted), 4)
        try:
            corr, _ = pearsonr(y_truth, y_forecasted)
            pearson = round(corr, 4)
        except:
            pearson = None

        return mae, mape, mse, rmse, rmspe, r2, pearson
    
    def prediction(self, best_params, current_datetime):
        
        p = best_params['p_order']
        d = best_params['d_order']
        q = best_params['q_order']

        if self.periodicity == '1_day':
            train_datetime = (current_datetime - pd.Timedelta(days = 1))

        if self.periodicity == '1_hour':
            train_datetime = (current_datetime - pd.Timedelta(hours = 1))

        model = ARIMA(self.df[:train_datetime], order = (p, d, q))
        fit_model = model.fit()
        
        pred = fit_model.predict(start = current_datetime, end = current_datetime)
        print('train_datetime ->', train_datetime)
        print('self.df[:train_datetime] ->', self.df[:train_datetime].index[-1])
        #integration
        if d == 1:
            
            last_close_price = self.df[:current_datetime].values[-1]
            pred = last_close_price + pred
            
        if d == 2:
            
            last_close_price = self.df[:current_datetime].values[-1]
            before_last_close_price = self.df[:current_datetime].values[-2]
            last_close_diff_price = last_close_price - before_last_close_price
            pred = last_close_price + last_close_diff_price + pred
        
        return pred
        
    def grid_search_model(self):
        
        train_size = int(len(self.df) * self.percentage_train_size)
        
        best_aic = np.inf 
        best_params = None
        best_fit = None

        p_range = range(10)
        d_range = range(3) # [0,1,2]

        for d in d_range:
            for p in p_range:
                try:
                    model = ARIMA(self.df[:train_size], order=(p, d, 0))

                    fit_model = model.fit()

                    if fit_model.aic < best_aic:
                        
                        best_aic = fit_model.aic
                        best_params = {'p_order': p, 'd_order': d, 'q_order': 0}
                        best_fit = fit_model

                except: continue

        print('AIC', best_aic, 'best_params', best_params)
        
        y_train_predict = best_fit.fittedvalues
        
        return best_params, train_size, y_train_predict

# %%
### MAIN

df = df_gemini_price_d.copy()
# df = df_gemini_price_1h.copy()

df = df.set_index('Date')
df = df.sort_values(by = ['Date'])
df = df.loc[:, ['Close']]

df = df.asfreq('D') # D or H

ar_forecast = ARForecast(df = df,
                         percentage_train_size = 0.80,
                         periodicity = '1_day'
                        )
df_train, df_test = ar_forecast.perform()
# Out:
# AIC 18628.20857982622 best_params {'p_order': 9, 'd_order': 1, 'q_order': 0}
# train_datetime -> 2019-05-15 00:00:00
# self.df[:train_datetime] -> 2019-05-15 00:00:00
# current_datetime -> 2019-05-16 00:00:00
# pred -> 2019-05-16    8038.997731
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-16 00:00:00
# self.df[:train_datetime] -> 2019-05-16 00:00:00
# current_datetime -> 2019-05-17 00:00:00
# pred -> 2019-05-17    7227.095412
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-17 00:00:00
# self.df[:train_datetime] -> 2019-05-17 00:00:00
# current_datetime -> 2019-05-18 00:00:00
# pred -> 2019-05-18    7347.046606
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-18 00:00:00
# self.df[:train_datetime] -> 2019-05-18 00:00:00
# current_datetime -> 2019-05-19 00:00:00
# pred -> 2019-05-19    8206.807963
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-19 00:00:00
# self.df[:train_datetime] -> 2019-05-19 00:00:00
# current_datetime -> 2019-05-20 00:00:00
# pred -> 2019-05-20    8073.626125
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-20 00:00:00
# self.df[:train_datetime] -> 2019-05-20 00:00:00
# current_datetime -> 2019-05-21 00:00:00
# pred -> 2019-05-21    7953.384181
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-21 00:00:00
# self.df[:train_datetime] -> 2019-05-21 00:00:00
# current_datetime -> 2019-05-22 00:00:00
# pred -> 2019-05-22    7628.677441
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-22 00:00:00
# self.df[:train_datetime] -> 2019-05-22 00:00:00
# current_datetime -> 2019-05-23 00:00:00
# pred -> 2019-05-23    7858.495896
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-23 00:00:00
# self.df[:train_datetime] -> 2019-05-23 00:00:00
# current_datetime -> 2019-05-24 00:00:00
# pred -> 2019-05-24    8175.363244
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-24 00:00:00
# self.df[:train_datetime] -> 2019-05-24 00:00:00
# current_datetime -> 2019-05-25 00:00:00
# pred -> 2019-05-25    7967.482982
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-25 00:00:00
# self.df[:train_datetime] -> 2019-05-25 00:00:00
# current_datetime -> 2019-05-26 00:00:00
# pred -> 2019-05-26    8717.086876
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-26 00:00:00
# self.df[:train_datetime] -> 2019-05-26 00:00:00
# current_datetime -> 2019-05-27 00:00:00
# pred -> 2019-05-27    8831.6028
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-27 00:00:00
# self.df[:train_datetime] -> 2019-05-27 00:00:00
# current_datetime -> 2019-05-28 00:00:00
# pred -> 2019-05-28    8796.211264
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-28 00:00:00
# self.df[:train_datetime] -> 2019-05-28 00:00:00
# current_datetime -> 2019-05-29 00:00:00
# pred -> 2019-05-29    8673.997697
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-29 00:00:00
# self.df[:train_datetime] -> 2019-05-29 00:00:00
# current_datetime -> 2019-05-30 00:00:00
# pred -> 2019-05-30    8207.849848
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-30 00:00:00
# self.df[:train_datetime] -> 2019-05-30 00:00:00
# current_datetime -> 2019-05-31 00:00:00
# pred -> 2019-05-31    8581.629132
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-05-31 00:00:00
# self.df[:train_datetime] -> 2019-05-31 00:00:00
# current_datetime -> 2019-06-01 00:00:00
# pred -> 2019-06-01    8568.317021
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-01 00:00:00
# self.df[:train_datetime] -> 2019-06-01 00:00:00
# current_datetime -> 2019-06-02 00:00:00
# pred -> 2019-06-02    8722.457091
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-02 00:00:00
# self.df[:train_datetime] -> 2019-06-02 00:00:00
# current_datetime -> 2019-06-03 00:00:00
# pred -> 2019-06-03    8189.389085
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-03 00:00:00
# self.df[:train_datetime] -> 2019-06-03 00:00:00
# current_datetime -> 2019-06-04 00:00:00
# pred -> 2019-06-04    7615.376784
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-04 00:00:00
# self.df[:train_datetime] -> 2019-06-04 00:00:00
# current_datetime -> 2019-06-05 00:00:00
# pred -> 2019-06-05    7829.756833
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-05 00:00:00
# self.df[:train_datetime] -> 2019-06-05 00:00:00
# current_datetime -> 2019-06-06 00:00:00
# pred -> 2019-06-06    7800.052711
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-06 00:00:00
# self.df[:train_datetime] -> 2019-06-06 00:00:00
# current_datetime -> 2019-06-07 00:00:00
# pred -> 2019-06-07    8025.894154
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-07 00:00:00
# self.df[:train_datetime] -> 2019-06-07 00:00:00
# current_datetime -> 2019-06-08 00:00:00
# pred -> 2019-06-08    7885.848403
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-08 00:00:00
# self.df[:train_datetime] -> 2019-06-08 00:00:00
# current_datetime -> 2019-06-09 00:00:00
# pred -> 2019-06-09    7618.145448
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-09 00:00:00
# self.df[:train_datetime] -> 2019-06-09 00:00:00
# current_datetime -> 2019-06-10 00:00:00
# pred -> 2019-06-10    8089.277246
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-10 00:00:00
# self.df[:train_datetime] -> 2019-06-10 00:00:00
# current_datetime -> 2019-06-11 00:00:00
# pred -> 2019-06-11    7918.550825
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-11 00:00:00
# self.df[:train_datetime] -> 2019-06-11 00:00:00
# current_datetime -> 2019-06-12 00:00:00
# pred -> 2019-06-12    8152.917153
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-12 00:00:00
# self.df[:train_datetime] -> 2019-06-12 00:00:00
# current_datetime -> 2019-06-13 00:00:00
# pred -> 2019-06-13    8272.583009
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-13 00:00:00
# self.df[:train_datetime] -> 2019-06-13 00:00:00
# current_datetime -> 2019-06-14 00:00:00
# pred -> 2019-06-14    8643.400485
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-14 00:00:00
# self.df[:train_datetime] -> 2019-06-14 00:00:00
# current_datetime -> 2019-06-15 00:00:00
# pred -> 2019-06-15    8974.139641
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-15 00:00:00
# self.df[:train_datetime] -> 2019-06-15 00:00:00
# current_datetime -> 2019-06-16 00:00:00
# pred -> 2019-06-16    8965.619504
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-16 00:00:00
# self.df[:train_datetime] -> 2019-06-16 00:00:00
# current_datetime -> 2019-06-17 00:00:00
# pred -> 2019-06-17    9350.162772
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-17 00:00:00
# self.df[:train_datetime] -> 2019-06-17 00:00:00
# current_datetime -> 2019-06-18 00:00:00
# pred -> 2019-06-18    9100.3556
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-18 00:00:00
# self.df[:train_datetime] -> 2019-06-18 00:00:00
# current_datetime -> 2019-06-19 00:00:00
# pred -> 2019-06-19    9314.690177
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-19 00:00:00
# self.df[:train_datetime] -> 2019-06-19 00:00:00
# current_datetime -> 2019-06-20 00:00:00
# pred -> 2019-06-20    9553.604241
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-20 00:00:00
# self.df[:train_datetime] -> 2019-06-20 00:00:00
# current_datetime -> 2019-06-21 00:00:00
# pred -> 2019-06-21    10234.371205
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-21 00:00:00
# self.df[:train_datetime] -> 2019-06-21 00:00:00
# current_datetime -> 2019-06-22 00:00:00
# pred -> 2019-06-22    10798.907048
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-22 00:00:00
# self.df[:train_datetime] -> 2019-06-22 00:00:00
# current_datetime -> 2019-06-23 00:00:00
# pred -> 2019-06-23    10829.198938
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-23 00:00:00
# self.df[:train_datetime] -> 2019-06-23 00:00:00
# current_datetime -> 2019-06-24 00:00:00
# pred -> 2019-06-24    11085.960617
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-24 00:00:00
# self.df[:train_datetime] -> 2019-06-24 00:00:00
# current_datetime -> 2019-06-25 00:00:00
# pred -> 2019-06-25    11800.971923
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-25 00:00:00
# self.df[:train_datetime] -> 2019-06-25 00:00:00
# current_datetime -> 2019-06-26 00:00:00
# pred -> 2019-06-26    13038.848559
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-26 00:00:00
# self.df[:train_datetime] -> 2019-06-26 00:00:00
# current_datetime -> 2019-06-27 00:00:00
# pred -> 2019-06-27    11248.590786
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-27 00:00:00
# self.df[:train_datetime] -> 2019-06-27 00:00:00
# current_datetime -> 2019-06-28 00:00:00
# pred -> 2019-06-28    12283.24086
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-28 00:00:00
# self.df[:train_datetime] -> 2019-06-28 00:00:00
# current_datetime -> 2019-06-29 00:00:00
# pred -> 2019-06-29    11968.015325
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-29 00:00:00
# self.df[:train_datetime] -> 2019-06-29 00:00:00
# current_datetime -> 2019-06-30 00:00:00
# pred -> 2019-06-30    10798.743728
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-06-30 00:00:00
# self.df[:train_datetime] -> 2019-06-30 00:00:00
# current_datetime -> 2019-07-01 00:00:00
# pred -> 2019-07-01    10717.726558
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-01 00:00:00
# self.df[:train_datetime] -> 2019-07-01 00:00:00
# current_datetime -> 2019-07-02 00:00:00
# pred -> 2019-07-02    10438.160762
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-02 00:00:00
# self.df[:train_datetime] -> 2019-07-02 00:00:00
# current_datetime -> 2019-07-03 00:00:00
# pred -> 2019-07-03    12237.384924
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-03 00:00:00
# self.df[:train_datetime] -> 2019-07-03 00:00:00
# current_datetime -> 2019-07-04 00:00:00
# pred -> 2019-07-04    11222.595154
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-04 00:00:00
# self.df[:train_datetime] -> 2019-07-04 00:00:00
# current_datetime -> 2019-07-05 00:00:00
# pred -> 2019-07-05    10824.397296
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-05 00:00:00
# self.df[:train_datetime] -> 2019-07-05 00:00:00
# current_datetime -> 2019-07-06 00:00:00
# pred -> 2019-07-06    11322.182383
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-06 00:00:00
# self.df[:train_datetime] -> 2019-07-06 00:00:00
# current_datetime -> 2019-07-07 00:00:00
# pred -> 2019-07-07    11510.93549
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-07 00:00:00
# self.df[:train_datetime] -> 2019-07-07 00:00:00
# current_datetime -> 2019-07-08 00:00:00
# pred -> 2019-07-08    12405.371602
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-08 00:00:00
# self.df[:train_datetime] -> 2019-07-08 00:00:00
# current_datetime -> 2019-07-09 00:00:00
# pred -> 2019-07-09    12370.573431
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-09 00:00:00
# self.df[:train_datetime] -> 2019-07-09 00:00:00
# current_datetime -> 2019-07-10 00:00:00
# pred -> 2019-07-10    12133.471394
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-10 00:00:00
# self.df[:train_datetime] -> 2019-07-10 00:00:00
# current_datetime -> 2019-07-11 00:00:00
# pred -> 2019-07-11    11417.78252
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-11 00:00:00
# self.df[:train_datetime] -> 2019-07-11 00:00:00
# current_datetime -> 2019-07-12 00:00:00
# pred -> 2019-07-12    11745.161309
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-12 00:00:00
# self.df[:train_datetime] -> 2019-07-12 00:00:00
# current_datetime -> 2019-07-13 00:00:00
# pred -> 2019-07-13    11460.379134
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-13 00:00:00
# self.df[:train_datetime] -> 2019-07-13 00:00:00
# current_datetime -> 2019-07-14 00:00:00
# pred -> 2019-07-14    10171.012587
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-14 00:00:00
# self.df[:train_datetime] -> 2019-07-14 00:00:00
# current_datetime -> 2019-07-15 00:00:00
# pred -> 2019-07-15    10797.010089
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-15 00:00:00
# self.df[:train_datetime] -> 2019-07-15 00:00:00
# current_datetime -> 2019-07-16 00:00:00
# pred -> 2019-07-16    9410.346509
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-16 00:00:00
# self.df[:train_datetime] -> 2019-07-16 00:00:00
# current_datetime -> 2019-07-17 00:00:00
# pred -> 2019-07-17    9793.553328
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-17 00:00:00
# self.df[:train_datetime] -> 2019-07-17 00:00:00
# current_datetime -> 2019-07-18 00:00:00
# pred -> 2019-07-18    10689.626351
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-18 00:00:00
# self.df[:train_datetime] -> 2019-07-18 00:00:00
# current_datetime -> 2019-07-19 00:00:00
# pred -> 2019-07-19    10303.298318
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-19 00:00:00
# self.df[:train_datetime] -> 2019-07-19 00:00:00
# current_datetime -> 2019-07-20 00:00:00
# pred -> 2019-07-20    10979.990477
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-20 00:00:00
# self.df[:train_datetime] -> 2019-07-20 00:00:00
# current_datetime -> 2019-07-21 00:00:00
# pred -> 2019-07-21    10428.628095
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-21 00:00:00
# self.df[:train_datetime] -> 2019-07-21 00:00:00
# current_datetime -> 2019-07-22 00:00:00
# pred -> 2019-07-22    10361.417372
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-22 00:00:00
# self.df[:train_datetime] -> 2019-07-22 00:00:00
# current_datetime -> 2019-07-23 00:00:00
# pred -> 2019-07-23    9955.464682
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-23 00:00:00
# self.df[:train_datetime] -> 2019-07-23 00:00:00
# current_datetime -> 2019-07-24 00:00:00
# pred -> 2019-07-24    9691.336379
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-24 00:00:00
# self.df[:train_datetime] -> 2019-07-24 00:00:00
# current_datetime -> 2019-07-25 00:00:00
# pred -> 2019-07-25    9897.146202
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-25 00:00:00
# self.df[:train_datetime] -> 2019-07-25 00:00:00
# current_datetime -> 2019-07-26 00:00:00
# pred -> 2019-07-26    9843.16221
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-26 00:00:00
# self.df[:train_datetime] -> 2019-07-26 00:00:00
# current_datetime -> 2019-07-27 00:00:00
# pred -> 2019-07-27    9519.160117
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-27 00:00:00
# self.df[:train_datetime] -> 2019-07-27 00:00:00
# current_datetime -> 2019-07-28 00:00:00
# pred -> 2019-07-28    9487.835709
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-28 00:00:00
# self.df[:train_datetime] -> 2019-07-28 00:00:00
# current_datetime -> 2019-07-29 00:00:00
# pred -> 2019-07-29    9539.103821
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-29 00:00:00
# self.df[:train_datetime] -> 2019-07-29 00:00:00
# current_datetime -> 2019-07-30 00:00:00
# pred -> 2019-07-30    9612.01046
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-30 00:00:00
# self.df[:train_datetime] -> 2019-07-30 00:00:00
# current_datetime -> 2019-07-31 00:00:00
# pred -> 2019-07-31    10085.528797
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-07-31 00:00:00
# self.df[:train_datetime] -> 2019-07-31 00:00:00
# current_datetime -> 2019-08-01 00:00:00
# pred -> 2019-08-01    10361.008501
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-01 00:00:00
# self.df[:train_datetime] -> 2019-08-01 00:00:00
# current_datetime -> 2019-08-02 00:00:00
# pred -> 2019-08-02    10565.657392
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-02 00:00:00
# self.df[:train_datetime] -> 2019-08-02 00:00:00
# current_datetime -> 2019-08-03 00:00:00
# pred -> 2019-08-03    10834.941776
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-03 00:00:00
# self.df[:train_datetime] -> 2019-08-03 00:00:00
# current_datetime -> 2019-08-04 00:00:00
# pred -> 2019-08-04    10978.245642
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-04 00:00:00
# self.df[:train_datetime] -> 2019-08-04 00:00:00
# current_datetime -> 2019-08-05 00:00:00
# pred -> 2019-08-05    11846.179362
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-05 00:00:00
# self.df[:train_datetime] -> 2019-08-05 00:00:00
# current_datetime -> 2019-08-06 00:00:00
# pred -> 2019-08-06    11506.520956
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-06 00:00:00
# self.df[:train_datetime] -> 2019-08-06 00:00:00
# current_datetime -> 2019-08-07 00:00:00
# pred -> 2019-08-07    11932.924231
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-07 00:00:00
# self.df[:train_datetime] -> 2019-08-07 00:00:00
# current_datetime -> 2019-08-08 00:00:00
# pred -> 2019-08-08    11921.603363
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-08 00:00:00
# self.df[:train_datetime] -> 2019-08-08 00:00:00
# current_datetime -> 2019-08-09 00:00:00
# pred -> 2019-08-09    11806.226252
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-09 00:00:00
# self.df[:train_datetime] -> 2019-08-09 00:00:00
# current_datetime -> 2019-08-10 00:00:00
# pred -> 2019-08-10    11437.607051
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-10 00:00:00
# self.df[:train_datetime] -> 2019-08-10 00:00:00
# current_datetime -> 2019-08-11 00:00:00
# pred -> 2019-08-11    11397.549685
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-11 00:00:00
# self.df[:train_datetime] -> 2019-08-11 00:00:00
# current_datetime -> 2019-08-12 00:00:00
# pred -> 2019-08-12    11489.50617
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-12 00:00:00
# self.df[:train_datetime] -> 2019-08-12 00:00:00
# current_datetime -> 2019-08-13 00:00:00
# pred -> 2019-08-13    10806.354563
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-13 00:00:00
# self.df[:train_datetime] -> 2019-08-13 00:00:00
# current_datetime -> 2019-08-14 00:00:00
# pred -> 2019-08-14    10082.249386
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-14 00:00:00
# self.df[:train_datetime] -> 2019-08-14 00:00:00
# current_datetime -> 2019-08-15 00:00:00
# pred -> 2019-08-15    10205.144244
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-15 00:00:00
# self.df[:train_datetime] -> 2019-08-15 00:00:00
# current_datetime -> 2019-08-16 00:00:00
# pred -> 2019-08-16    10443.235971
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-16 00:00:00
# self.df[:train_datetime] -> 2019-08-16 00:00:00
# current_datetime -> 2019-08-17 00:00:00
# pred -> 2019-08-17    10175.054152
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-17 00:00:00
# self.df[:train_datetime] -> 2019-08-17 00:00:00
# current_datetime -> 2019-08-18 00:00:00
# pred -> 2019-08-18    10312.144484
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-18 00:00:00
# self.df[:train_datetime] -> 2019-08-18 00:00:00
# current_datetime -> 2019-08-19 00:00:00
# pred -> 2019-08-19    10846.425383
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-19 00:00:00
# self.df[:train_datetime] -> 2019-08-19 00:00:00
# current_datetime -> 2019-08-20 00:00:00
# pred -> 2019-08-20    10850.078163
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-20 00:00:00
# self.df[:train_datetime] -> 2019-08-20 00:00:00
# current_datetime -> 2019-08-21 00:00:00
# pred -> 2019-08-21    10135.769503
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-21 00:00:00
# self.df[:train_datetime] -> 2019-08-21 00:00:00
# current_datetime -> 2019-08-22 00:00:00
# pred -> 2019-08-22    10137.595824
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-22 00:00:00
# self.df[:train_datetime] -> 2019-08-22 00:00:00
# current_datetime -> 2019-08-23 00:00:00
# pred -> 2019-08-23    10404.522399
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-23 00:00:00
# self.df[:train_datetime] -> 2019-08-23 00:00:00
# current_datetime -> 2019-08-24 00:00:00
# pred -> 2019-08-24    10214.167199
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-24 00:00:00
# self.df[:train_datetime] -> 2019-08-24 00:00:00
# current_datetime -> 2019-08-25 00:00:00
# pred -> 2019-08-25    10103.355583
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-25 00:00:00
# self.df[:train_datetime] -> 2019-08-25 00:00:00
# current_datetime -> 2019-08-26 00:00:00
# pred -> 2019-08-26    10322.528858
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-26 00:00:00
# self.df[:train_datetime] -> 2019-08-26 00:00:00
# current_datetime -> 2019-08-27 00:00:00
# pred -> 2019-08-27    10217.729744
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-27 00:00:00
# self.df[:train_datetime] -> 2019-08-27 00:00:00
# current_datetime -> 2019-08-28 00:00:00
# pred -> 2019-08-28    9772.014815
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-28 00:00:00
# self.df[:train_datetime] -> 2019-08-28 00:00:00
# current_datetime -> 2019-08-29 00:00:00
# pred -> 2019-08-29    9449.288549
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-29 00:00:00
# self.df[:train_datetime] -> 2019-08-29 00:00:00
# current_datetime -> 2019-08-30 00:00:00
# pred -> 2019-08-30    9582.081465
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-30 00:00:00
# self.df[:train_datetime] -> 2019-08-30 00:00:00
# current_datetime -> 2019-08-31 00:00:00
# pred -> 2019-08-31    9639.646456
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-08-31 00:00:00
# self.df[:train_datetime] -> 2019-08-31 00:00:00
# current_datetime -> 2019-09-01 00:00:00
# pred -> 2019-09-01    9753.455942
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-01 00:00:00
# self.df[:train_datetime] -> 2019-09-01 00:00:00
# current_datetime -> 2019-09-02 00:00:00
# pred -> 2019-09-02    10375.128533
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-02 00:00:00
# self.df[:train_datetime] -> 2019-09-02 00:00:00
# current_datetime -> 2019-09-03 00:00:00
# pred -> 2019-09-03    10643.674094
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-03 00:00:00
# self.df[:train_datetime] -> 2019-09-03 00:00:00
# current_datetime -> 2019-09-04 00:00:00
# pred -> 2019-09-04    10616.034689
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-04 00:00:00
# self.df[:train_datetime] -> 2019-09-04 00:00:00
# current_datetime -> 2019-09-05 00:00:00
# pred -> 2019-09-05    10607.729092
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-05 00:00:00
# self.df[:train_datetime] -> 2019-09-05 00:00:00
# current_datetime -> 2019-09-06 00:00:00
# pred -> 2019-09-06    10348.620925
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-06 00:00:00
# self.df[:train_datetime] -> 2019-09-06 00:00:00
# current_datetime -> 2019-09-07 00:00:00
# pred -> 2019-09-07    10524.855505
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-07 00:00:00
# self.df[:train_datetime] -> 2019-09-07 00:00:00
# current_datetime -> 2019-09-08 00:00:00
# pred -> 2019-09-08    10409.478658
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-08 00:00:00
# self.df[:train_datetime] -> 2019-09-08 00:00:00
# current_datetime -> 2019-09-09 00:00:00
# pred -> 2019-09-09    10286.054637
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-09 00:00:00
# self.df[:train_datetime] -> 2019-09-09 00:00:00
# current_datetime -> 2019-09-10 00:00:00
# pred -> 2019-09-10    10134.518871
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-10 00:00:00
# self.df[:train_datetime] -> 2019-09-10 00:00:00
# current_datetime -> 2019-09-11 00:00:00
# pred -> 2019-09-11    10137.086682
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-11 00:00:00
# self.df[:train_datetime] -> 2019-09-11 00:00:00
# current_datetime -> 2019-09-12 00:00:00
# pred -> 2019-09-12    10476.565056
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-12 00:00:00
# self.df[:train_datetime] -> 2019-09-12 00:00:00
# current_datetime -> 2019-09-13 00:00:00
# pred -> 2019-09-13    10351.473722
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-13 00:00:00
# self.df[:train_datetime] -> 2019-09-13 00:00:00
# current_datetime -> 2019-09-14 00:00:00
# pred -> 2019-09-14    10364.144486
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-14 00:00:00
# self.df[:train_datetime] -> 2019-09-14 00:00:00
# current_datetime -> 2019-09-15 00:00:00
# pred -> 2019-09-15    10312.971996
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-15 00:00:00
# self.df[:train_datetime] -> 2019-09-15 00:00:00
# current_datetime -> 2019-09-16 00:00:00
# pred -> 2019-09-16    10282.90366
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-16 00:00:00
# self.df[:train_datetime] -> 2019-09-16 00:00:00
# current_datetime -> 2019-09-17 00:00:00
# pred -> 2019-09-17    10226.403942
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-17 00:00:00
# self.df[:train_datetime] -> 2019-09-17 00:00:00
# current_datetime -> 2019-09-18 00:00:00
# pred -> 2019-09-18    10138.249518
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-18 00:00:00
# self.df[:train_datetime] -> 2019-09-18 00:00:00
# current_datetime -> 2019-09-19 00:00:00
# pred -> 2019-09-19    10249.979103
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-19 00:00:00
# self.df[:train_datetime] -> 2019-09-19 00:00:00
# current_datetime -> 2019-09-20 00:00:00
# pred -> 2019-09-20    10175.684831
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-20 00:00:00
# self.df[:train_datetime] -> 2019-09-20 00:00:00
# current_datetime -> 2019-09-21 00:00:00
# pred -> 2019-09-21    9987.344414
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-21 00:00:00
# self.df[:train_datetime] -> 2019-09-21 00:00:00
# current_datetime -> 2019-09-22 00:00:00
# pred -> 2019-09-22    10033.605395
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-22 00:00:00
# self.df[:train_datetime] -> 2019-09-22 00:00:00
# current_datetime -> 2019-09-23 00:00:00
# pred -> 2019-09-23    9700.344306
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-23 00:00:00
# self.df[:train_datetime] -> 2019-09-23 00:00:00
# current_datetime -> 2019-09-24 00:00:00
# pred -> 2019-09-24    8547.486093
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-24 00:00:00
# self.df[:train_datetime] -> 2019-09-24 00:00:00
# current_datetime -> 2019-09-25 00:00:00
# pred -> 2019-09-25    8414.531542
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-25 00:00:00
# self.df[:train_datetime] -> 2019-09-25 00:00:00
# current_datetime -> 2019-09-26 00:00:00
# pred -> 2019-09-26    8059.65619
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-26 00:00:00
# self.df[:train_datetime] -> 2019-09-26 00:00:00
# current_datetime -> 2019-09-27 00:00:00
# pred -> 2019-09-27    8183.214964
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-27 00:00:00
# self.df[:train_datetime] -> 2019-09-27 00:00:00
# current_datetime -> 2019-09-28 00:00:00
# pred -> 2019-09-28    8253.699871
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-28 00:00:00
# self.df[:train_datetime] -> 2019-09-28 00:00:00
# current_datetime -> 2019-09-29 00:00:00
# pred -> 2019-09-29    7948.335241
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-29 00:00:00
# self.df[:train_datetime] -> 2019-09-29 00:00:00
# current_datetime -> 2019-09-30 00:00:00
# pred -> 2019-09-30    8386.794954
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-09-30 00:00:00
# self.df[:train_datetime] -> 2019-09-30 00:00:00
# current_datetime -> 2019-10-01 00:00:00
# pred -> 2019-10-01    8311.070361
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-01 00:00:00
# self.df[:train_datetime] -> 2019-10-01 00:00:00
# current_datetime -> 2019-10-02 00:00:00
# pred -> 2019-10-02    8400.678274
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-02 00:00:00
# self.df[:train_datetime] -> 2019-10-02 00:00:00
# current_datetime -> 2019-10-03 00:00:00
# pred -> 2019-10-03    8214.13473
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-03 00:00:00
# self.df[:train_datetime] -> 2019-10-03 00:00:00
# current_datetime -> 2019-10-04 00:00:00
# pred -> 2019-10-04    8120.796576
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-04 00:00:00
# self.df[:train_datetime] -> 2019-10-04 00:00:00
# current_datetime -> 2019-10-05 00:00:00
# pred -> 2019-10-05    8193.174903
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-05 00:00:00
# self.df[:train_datetime] -> 2019-10-05 00:00:00
# current_datetime -> 2019-10-06 00:00:00
# pred -> 2019-10-06    7846.046568
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-06 00:00:00
# self.df[:train_datetime] -> 2019-10-06 00:00:00
# current_datetime -> 2019-10-07 00:00:00
# pred -> 2019-10-07    8214.288339
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-07 00:00:00
# self.df[:train_datetime] -> 2019-10-07 00:00:00
# current_datetime -> 2019-10-08 00:00:00
# pred -> 2019-10-08    8186.887184
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-08 00:00:00
# self.df[:train_datetime] -> 2019-10-08 00:00:00
# current_datetime -> 2019-10-09 00:00:00
# pred -> 2019-10-09    8588.843124
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-09 00:00:00
# self.df[:train_datetime] -> 2019-10-09 00:00:00
# current_datetime -> 2019-10-10 00:00:00
# pred -> 2019-10-10    8636.190814
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-10 00:00:00
# self.df[:train_datetime] -> 2019-10-10 00:00:00
# current_datetime -> 2019-10-11 00:00:00
# pred -> 2019-10-11    8222.559022
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-11 00:00:00
# self.df[:train_datetime] -> 2019-10-11 00:00:00
# current_datetime -> 2019-10-12 00:00:00
# pred -> 2019-10-12    8382.218327
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-12 00:00:00
# self.df[:train_datetime] -> 2019-10-12 00:00:00
# current_datetime -> 2019-10-13 00:00:00
# pred -> 2019-10-13    8243.256538
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-13 00:00:00
# self.df[:train_datetime] -> 2019-10-13 00:00:00
# current_datetime -> 2019-10-14 00:00:00
# pred -> 2019-10-14    8387.201956
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-14 00:00:00
# self.df[:train_datetime] -> 2019-10-14 00:00:00
# current_datetime -> 2019-10-15 00:00:00
# pred -> 2019-10-15    8160.583276
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-15 00:00:00
# self.df[:train_datetime] -> 2019-10-15 00:00:00
# current_datetime -> 2019-10-16 00:00:00
# pred -> 2019-10-16    7967.123446
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-16 00:00:00
# self.df[:train_datetime] -> 2019-10-16 00:00:00
# current_datetime -> 2019-10-17 00:00:00
# pred -> 2019-10-17    8113.497486
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-17 00:00:00
# self.df[:train_datetime] -> 2019-10-17 00:00:00
# current_datetime -> 2019-10-18 00:00:00
# pred -> 2019-10-18    7958.504605
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-18 00:00:00
# self.df[:train_datetime] -> 2019-10-18 00:00:00
# current_datetime -> 2019-10-19 00:00:00
# pred -> 2019-10-19    7971.831054
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-19 00:00:00
# self.df[:train_datetime] -> 2019-10-19 00:00:00
# current_datetime -> 2019-10-20 00:00:00
# pred -> 2019-10-20    8215.245911
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-20 00:00:00
# self.df[:train_datetime] -> 2019-10-20 00:00:00
# current_datetime -> 2019-10-21 00:00:00
# pred -> 2019-10-21    8212.000084
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-21 00:00:00
# self.df[:train_datetime] -> 2019-10-21 00:00:00
# current_datetime -> 2019-10-22 00:00:00
# pred -> 2019-10-22    8048.194315
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-22 00:00:00
# self.df[:train_datetime] -> 2019-10-22 00:00:00
# current_datetime -> 2019-10-23 00:00:00
# pred -> 2019-10-23    7462.512277
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-23 00:00:00
# self.df[:train_datetime] -> 2019-10-23 00:00:00
# current_datetime -> 2019-10-24 00:00:00
# pred -> 2019-10-24    7443.313854
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-24 00:00:00
# self.df[:train_datetime] -> 2019-10-24 00:00:00
# current_datetime -> 2019-10-25 00:00:00
# pred -> 2019-10-25    8706.289122
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-25 00:00:00
# self.df[:train_datetime] -> 2019-10-25 00:00:00
# current_datetime -> 2019-10-26 00:00:00
# pred -> 2019-10-26    9276.680834
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-26 00:00:00
# self.df[:train_datetime] -> 2019-10-26 00:00:00
# current_datetime -> 2019-10-27 00:00:00
# pred -> 2019-10-27    9547.747371
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-27 00:00:00
# self.df[:train_datetime] -> 2019-10-27 00:00:00
# current_datetime -> 2019-10-28 00:00:00
# pred -> 2019-10-28    9217.613697
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-28 00:00:00
# self.df[:train_datetime] -> 2019-10-28 00:00:00
# current_datetime -> 2019-10-29 00:00:00
# pred -> 2019-10-29    9418.615911
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-29 00:00:00
# self.df[:train_datetime] -> 2019-10-29 00:00:00
# current_datetime -> 2019-10-30 00:00:00
# pred -> 2019-10-30    9303.328573
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-30 00:00:00
# self.df[:train_datetime] -> 2019-10-30 00:00:00
# current_datetime -> 2019-10-31 00:00:00
# pred -> 2019-10-31    9098.770854
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-10-31 00:00:00
# self.df[:train_datetime] -> 2019-10-31 00:00:00
# current_datetime -> 2019-11-01 00:00:00
# pred -> 2019-11-01    9261.620995
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-01 00:00:00
# self.df[:train_datetime] -> 2019-11-01 00:00:00
# current_datetime -> 2019-11-02 00:00:00
# pred -> 2019-11-02    9257.274784
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-02 00:00:00
# self.df[:train_datetime] -> 2019-11-02 00:00:00
# current_datetime -> 2019-11-03 00:00:00
# pred -> 2019-11-03    9280.986226
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-03 00:00:00
# self.df[:train_datetime] -> 2019-11-03 00:00:00
# current_datetime -> 2019-11-04 00:00:00
# pred -> 2019-11-04    9387.215624
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-04 00:00:00
# self.df[:train_datetime] -> 2019-11-04 00:00:00
# current_datetime -> 2019-11-05 00:00:00
# pred -> 2019-11-05    9343.329903
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-05 00:00:00
# self.df[:train_datetime] -> 2019-11-05 00:00:00
# current_datetime -> 2019-11-06 00:00:00
# pred -> 2019-11-06    9353.700133
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-06 00:00:00
# self.df[:train_datetime] -> 2019-11-06 00:00:00
# current_datetime -> 2019-11-07 00:00:00
# pred -> 2019-11-07    9221.707591
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-07 00:00:00
# self.df[:train_datetime] -> 2019-11-07 00:00:00
# current_datetime -> 2019-11-08 00:00:00
# pred -> 2019-11-08    8737.750911
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-08 00:00:00
# self.df[:train_datetime] -> 2019-11-08 00:00:00
# current_datetime -> 2019-11-09 00:00:00
# pred -> 2019-11-09    8842.012356
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-09 00:00:00
# self.df[:train_datetime] -> 2019-11-09 00:00:00
# current_datetime -> 2019-11-10 00:00:00
# pred -> 2019-11-10    9027.133338
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-10 00:00:00
# self.df[:train_datetime] -> 2019-11-10 00:00:00
# current_datetime -> 2019-11-11 00:00:00
# pred -> 2019-11-11    8735.39128
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-11 00:00:00
# self.df[:train_datetime] -> 2019-11-11 00:00:00
# current_datetime -> 2019-11-12 00:00:00
# pred -> 2019-11-12    8813.005974
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-12 00:00:00
# self.df[:train_datetime] -> 2019-11-12 00:00:00
# current_datetime -> 2019-11-13 00:00:00
# pred -> 2019-11-13    8745.95001
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-13 00:00:00
# self.df[:train_datetime] -> 2019-11-13 00:00:00
# current_datetime -> 2019-11-14 00:00:00
# pred -> 2019-11-14    8639.725759
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-14 00:00:00
# self.df[:train_datetime] -> 2019-11-14 00:00:00
# current_datetime -> 2019-11-15 00:00:00
# pred -> 2019-11-15    8499.981605
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-15 00:00:00
# self.df[:train_datetime] -> 2019-11-15 00:00:00
# current_datetime -> 2019-11-16 00:00:00
# pred -> 2019-11-16    8421.388207
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-16 00:00:00
# self.df[:train_datetime] -> 2019-11-16 00:00:00
# current_datetime -> 2019-11-17 00:00:00
# pred -> 2019-11-17    8534.162719
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-17 00:00:00
# self.df[:train_datetime] -> 2019-11-17 00:00:00
# current_datetime -> 2019-11-18 00:00:00
# pred -> 2019-11-18    8173.412793
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-18 00:00:00
# self.df[:train_datetime] -> 2019-11-18 00:00:00
# current_datetime -> 2019-11-19 00:00:00
# pred -> 2019-11-19    8112.436204
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-19 00:00:00
# self.df[:train_datetime] -> 2019-11-19 00:00:00
# current_datetime -> 2019-11-20 00:00:00
# pred -> 2019-11-20    8078.274767
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-20 00:00:00
# self.df[:train_datetime] -> 2019-11-20 00:00:00
# current_datetime -> 2019-11-21 00:00:00
# pred -> 2019-11-21    7622.223394
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-21 00:00:00
# self.df[:train_datetime] -> 2019-11-21 00:00:00
# current_datetime -> 2019-11-22 00:00:00
# pred -> 2019-11-22    7292.349727
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-22 00:00:00
# self.df[:train_datetime] -> 2019-11-22 00:00:00
# current_datetime -> 2019-11-23 00:00:00
# pred -> 2019-11-23    7295.903407
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-23 00:00:00
# self.df[:train_datetime] -> 2019-11-23 00:00:00
# current_datetime -> 2019-11-24 00:00:00
# pred -> 2019-11-24    6926.318672
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-24 00:00:00
# self.df[:train_datetime] -> 2019-11-24 00:00:00
# current_datetime -> 2019-11-25 00:00:00
# pred -> 2019-11-25    7123.784306
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-25 00:00:00
# self.df[:train_datetime] -> 2019-11-25 00:00:00
# current_datetime -> 2019-11-26 00:00:00
# pred -> 2019-11-26    7148.755052
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-26 00:00:00
# self.df[:train_datetime] -> 2019-11-26 00:00:00
# current_datetime -> 2019-11-27 00:00:00
# pred -> 2019-11-27    7496.274155
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-27 00:00:00
# self.df[:train_datetime] -> 2019-11-27 00:00:00
# current_datetime -> 2019-11-28 00:00:00
# pred -> 2019-11-28    7496.526283
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-28 00:00:00
# self.df[:train_datetime] -> 2019-11-28 00:00:00
# current_datetime -> 2019-11-29 00:00:00
# pred -> 2019-11-29    7692.542723
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-29 00:00:00
# self.df[:train_datetime] -> 2019-11-29 00:00:00
# current_datetime -> 2019-11-30 00:00:00
# pred -> 2019-11-30    7619.451121
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-11-30 00:00:00
# self.df[:train_datetime] -> 2019-11-30 00:00:00
# current_datetime -> 2019-12-01 00:00:00
# pred -> 2019-12-01    7363.062029
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-01 00:00:00
# self.df[:train_datetime] -> 2019-12-01 00:00:00
# current_datetime -> 2019-12-02 00:00:00
# pred -> 2019-12-02    7349.374306
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-02 00:00:00
# self.df[:train_datetime] -> 2019-12-02 00:00:00
# current_datetime -> 2019-12-03 00:00:00
# pred -> 2019-12-03    7251.082679
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-03 00:00:00
# self.df[:train_datetime] -> 2019-12-03 00:00:00
# current_datetime -> 2019-12-04 00:00:00
# pred -> 2019-12-04    7244.59693
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-04 00:00:00
# self.df[:train_datetime] -> 2019-12-04 00:00:00
# current_datetime -> 2019-12-05 00:00:00
# pred -> 2019-12-05    7362.786559
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-05 00:00:00
# self.df[:train_datetime] -> 2019-12-05 00:00:00
# current_datetime -> 2019-12-06 00:00:00
# pred -> 2019-12-06    7558.270788
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-06 00:00:00
# self.df[:train_datetime] -> 2019-12-06 00:00:00
# current_datetime -> 2019-12-07 00:00:00
# pred -> 2019-12-07    7505.162996
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-07 00:00:00
# self.df[:train_datetime] -> 2019-12-07 00:00:00
# current_datetime -> 2019-12-08 00:00:00
# pred -> 2019-12-08    7546.808103
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-08 00:00:00
# self.df[:train_datetime] -> 2019-12-08 00:00:00
# current_datetime -> 2019-12-09 00:00:00
# pred -> 2019-12-09    7326.788485
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-09 00:00:00
# self.df[:train_datetime] -> 2019-12-09 00:00:00
# current_datetime -> 2019-12-10 00:00:00
# pred -> 2019-12-10    7235.934355
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-10 00:00:00
# self.df[:train_datetime] -> 2019-12-10 00:00:00
# current_datetime -> 2019-12-11 00:00:00
# pred -> 2019-12-11    7210.175464
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-11 00:00:00
# self.df[:train_datetime] -> 2019-12-11 00:00:00
# current_datetime -> 2019-12-12 00:00:00
# pred -> 2019-12-12    7176.498266
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-12 00:00:00
# self.df[:train_datetime] -> 2019-12-12 00:00:00
# current_datetime -> 2019-12-13 00:00:00
# pred -> 2019-12-13    7266.919023
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-13 00:00:00
# self.df[:train_datetime] -> 2019-12-13 00:00:00
# current_datetime -> 2019-12-14 00:00:00
# pred -> 2019-12-14    7067.100209
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-14 00:00:00
# self.df[:train_datetime] -> 2019-12-14 00:00:00
# current_datetime -> 2019-12-15 00:00:00
# pred -> 2019-12-15    7119.684431
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-15 00:00:00
# self.df[:train_datetime] -> 2019-12-15 00:00:00
# current_datetime -> 2019-12-16 00:00:00
# pred -> 2019-12-16    6897.77662
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-16 00:00:00
# self.df[:train_datetime] -> 2019-12-16 00:00:00
# current_datetime -> 2019-12-17 00:00:00
# pred -> 2019-12-17    6602.150334
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-17 00:00:00
# self.df[:train_datetime] -> 2019-12-17 00:00:00
# current_datetime -> 2019-12-18 00:00:00
# pred -> 2019-12-18    7306.519019
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-18 00:00:00
# self.df[:train_datetime] -> 2019-12-18 00:00:00
# current_datetime -> 2019-12-19 00:00:00
# pred -> 2019-12-19    7149.532097
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-19 00:00:00
# self.df[:train_datetime] -> 2019-12-19 00:00:00
# current_datetime -> 2019-12-20 00:00:00
# pred -> 2019-12-20    7193.343274
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-20 00:00:00
# self.df[:train_datetime] -> 2019-12-20 00:00:00
# current_datetime -> 2019-12-21 00:00:00
# pred -> 2019-12-21    7156.440761
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-21 00:00:00
# self.df[:train_datetime] -> 2019-12-21 00:00:00
# current_datetime -> 2019-12-22 00:00:00
# pred -> 2019-12-22    7463.855474
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-22 00:00:00
# self.df[:train_datetime] -> 2019-12-22 00:00:00
# current_datetime -> 2019-12-23 00:00:00
# pred -> 2019-12-23    7423.399887
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-23 00:00:00
# self.df[:train_datetime] -> 2019-12-23 00:00:00
# current_datetime -> 2019-12-24 00:00:00
# pred -> 2019-12-24    7192.461556
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-24 00:00:00
# self.df[:train_datetime] -> 2019-12-24 00:00:00
# current_datetime -> 2019-12-25 00:00:00
# pred -> 2019-12-25    7218.5394
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-25 00:00:00
# self.df[:train_datetime] -> 2019-12-25 00:00:00
# current_datetime -> 2019-12-26 00:00:00
# pred -> 2019-12-26    7175.884627
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-26 00:00:00
# self.df[:train_datetime] -> 2019-12-26 00:00:00
# current_datetime -> 2019-12-27 00:00:00
# pred -> 2019-12-27    7299.008074
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-27 00:00:00
# self.df[:train_datetime] -> 2019-12-27 00:00:00
# current_datetime -> 2019-12-28 00:00:00
# pred -> 2019-12-28    7263.280241
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-28 00:00:00
# self.df[:train_datetime] -> 2019-12-28 00:00:00
# current_datetime -> 2019-12-29 00:00:00
# pred -> 2019-12-29    7404.270963
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-29 00:00:00
# self.df[:train_datetime] -> 2019-12-29 00:00:00
# current_datetime -> 2019-12-30 00:00:00
# pred -> 2019-12-30    7224.371821
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-30 00:00:00
# self.df[:train_datetime] -> 2019-12-30 00:00:00
# current_datetime -> 2019-12-31 00:00:00
# pred -> 2019-12-31    7169.436658
# Freq: D, dtype: float64
# ---
# train_datetime -> 2019-12-31 00:00:00
# self.df[:train_datetime] -> 2019-12-31 00:00:00
# current_datetime -> 2020-01-01 00:00:00
# pred -> 2020-01-01    7183.472659
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-01 00:00:00
# self.df[:train_datetime] -> 2020-01-01 00:00:00
# current_datetime -> 2020-01-02 00:00:00
# pred -> 2020-01-02    6942.500271
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-02 00:00:00
# self.df[:train_datetime] -> 2020-01-02 00:00:00
# current_datetime -> 2020-01-03 00:00:00
# pred -> 2020-01-03    7342.587308
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-03 00:00:00
# self.df[:train_datetime] -> 2020-01-03 00:00:00
# current_datetime -> 2020-01-04 00:00:00
# pred -> 2020-01-04    7351.061852
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-04 00:00:00
# self.df[:train_datetime] -> 2020-01-04 00:00:00
# current_datetime -> 2020-01-05 00:00:00
# pred -> 2020-01-05    7348.594797
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-05 00:00:00
# self.df[:train_datetime] -> 2020-01-05 00:00:00
# current_datetime -> 2020-01-06 00:00:00
# pred -> 2020-01-06    7795.384046
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-06 00:00:00
# self.df[:train_datetime] -> 2020-01-06 00:00:00
# current_datetime -> 2020-01-07 00:00:00
# pred -> 2020-01-07    8130.154586
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-07 00:00:00
# self.df[:train_datetime] -> 2020-01-07 00:00:00
# current_datetime -> 2020-01-08 00:00:00
# pred -> 2020-01-08    8098.549938
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-08 00:00:00
# self.df[:train_datetime] -> 2020-01-08 00:00:00
# current_datetime -> 2020-01-09 00:00:00
# pred -> 2020-01-09    7805.76524
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-09 00:00:00
# self.df[:train_datetime] -> 2020-01-09 00:00:00
# current_datetime -> 2020-01-10 00:00:00
# pred -> 2020-01-10    8180.984721
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-10 00:00:00
# self.df[:train_datetime] -> 2020-01-10 00:00:00
# current_datetime -> 2020-01-11 00:00:00
# pred -> 2020-01-11    8062.675799
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-11 00:00:00
# self.df[:train_datetime] -> 2020-01-11 00:00:00
# current_datetime -> 2020-01-12 00:00:00
# pred -> 2020-01-12    8182.203064
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-12 00:00:00
# self.df[:train_datetime] -> 2020-01-12 00:00:00
# current_datetime -> 2020-01-13 00:00:00
# pred -> 2020-01-13    8108.38972
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-13 00:00:00
# self.df[:train_datetime] -> 2020-01-13 00:00:00
# current_datetime -> 2020-01-14 00:00:00
# pred -> 2020-01-14    8794.52719
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-14 00:00:00
# self.df[:train_datetime] -> 2020-01-14 00:00:00
# current_datetime -> 2020-01-15 00:00:00
# pred -> 2020-01-15    8907.583847
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-15 00:00:00
# self.df[:train_datetime] -> 2020-01-15 00:00:00
# current_datetime -> 2020-01-16 00:00:00
# pred -> 2020-01-16    8660.942841
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-16 00:00:00
# self.df[:train_datetime] -> 2020-01-16 00:00:00
# current_datetime -> 2020-01-17 00:00:00
# pred -> 2020-01-17    8950.219222
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-17 00:00:00
# self.df[:train_datetime] -> 2020-01-17 00:00:00
# current_datetime -> 2020-01-18 00:00:00
# pred -> 2020-01-18    8873.682501
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-18 00:00:00
# self.df[:train_datetime] -> 2020-01-18 00:00:00
# current_datetime -> 2020-01-19 00:00:00
# pred -> 2020-01-19    8775.090346
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-19 00:00:00
# self.df[:train_datetime] -> 2020-01-19 00:00:00
# current_datetime -> 2020-01-20 00:00:00
# pred -> 2020-01-20    8593.11279
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-20 00:00:00
# self.df[:train_datetime] -> 2020-01-20 00:00:00
# current_datetime -> 2020-01-21 00:00:00
# pred -> 2020-01-21    8709.214331
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-21 00:00:00
# self.df[:train_datetime] -> 2020-01-21 00:00:00
# current_datetime -> 2020-01-22 00:00:00
# pred -> 2020-01-22    8698.442093
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-22 00:00:00
# self.df[:train_datetime] -> 2020-01-22 00:00:00
# current_datetime -> 2020-01-23 00:00:00
# pred -> 2020-01-23    8395.447422
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-23 00:00:00
# self.df[:train_datetime] -> 2020-01-23 00:00:00
# current_datetime -> 2020-01-24 00:00:00
# pred -> 2020-01-24    8409.873979
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-24 00:00:00
# self.df[:train_datetime] -> 2020-01-24 00:00:00
# current_datetime -> 2020-01-25 00:00:00
# pred -> 2020-01-25    8343.063944
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-25 00:00:00
# self.df[:train_datetime] -> 2020-01-25 00:00:00
# current_datetime -> 2020-01-26 00:00:00
# pred -> 2020-01-26    8593.379387
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-26 00:00:00
# self.df[:train_datetime] -> 2020-01-26 00:00:00
# current_datetime -> 2020-01-27 00:00:00
# pred -> 2020-01-27    8914.038583
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-27 00:00:00
# self.df[:train_datetime] -> 2020-01-27 00:00:00
# current_datetime -> 2020-01-28 00:00:00
# pred -> 2020-01-28    9376.975425
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-28 00:00:00
# self.df[:train_datetime] -> 2020-01-28 00:00:00
# current_datetime -> 2020-01-29 00:00:00
# pred -> 2020-01-29    9324.476141
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-29 00:00:00
# self.df[:train_datetime] -> 2020-01-29 00:00:00
# current_datetime -> 2020-01-30 00:00:00
# pred -> 2020-01-30    9478.118858
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-30 00:00:00
# self.df[:train_datetime] -> 2020-01-30 00:00:00
# current_datetime -> 2020-01-31 00:00:00
# pred -> 2020-01-31    9371.420042
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-01-31 00:00:00
# self.df[:train_datetime] -> 2020-01-31 00:00:00
# current_datetime -> 2020-02-01 00:00:00
# pred -> 2020-02-01    9365.360578
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-01 00:00:00
# self.df[:train_datetime] -> 2020-02-01 00:00:00
# current_datetime -> 2020-02-02 00:00:00
# pred -> 2020-02-02    9369.075802
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-02 00:00:00
# self.df[:train_datetime] -> 2020-02-02 00:00:00
# current_datetime -> 2020-02-03 00:00:00
# pred -> 2020-02-03    9228.208386
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-03 00:00:00
# self.df[:train_datetime] -> 2020-02-03 00:00:00
# current_datetime -> 2020-02-04 00:00:00
# pred -> 2020-02-04    9215.487364
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-04 00:00:00
# self.df[:train_datetime] -> 2020-02-04 00:00:00
# current_datetime -> 2020-02-05 00:00:00
# pred -> 2020-02-05    9593.817173
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-05 00:00:00
# self.df[:train_datetime] -> 2020-02-05 00:00:00
# current_datetime -> 2020-02-06 00:00:00
# pred -> 2020-02-06    9797.081619
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-06 00:00:00
# self.df[:train_datetime] -> 2020-02-06 00:00:00
# current_datetime -> 2020-02-07 00:00:00
# pred -> 2020-02-07    9810.058528
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-07 00:00:00
# self.df[:train_datetime] -> 2020-02-07 00:00:00
# current_datetime -> 2020-02-08 00:00:00
# pred -> 2020-02-08    9934.516944
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-08 00:00:00
# self.df[:train_datetime] -> 2020-02-08 00:00:00
# current_datetime -> 2020-02-09 00:00:00
# pred -> 2020-02-09    10151.999388
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-09 00:00:00
# self.df[:train_datetime] -> 2020-02-09 00:00:00
# current_datetime -> 2020-02-10 00:00:00
# pred -> 2020-02-10    9913.482685
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-10 00:00:00
# self.df[:train_datetime] -> 2020-02-10 00:00:00
# current_datetime -> 2020-02-11 00:00:00
# pred -> 2020-02-11    10249.668251
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-11 00:00:00
# self.df[:train_datetime] -> 2020-02-11 00:00:00
# current_datetime -> 2020-02-12 00:00:00
# pred -> 2020-02-12    10370.606774
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-12 00:00:00
# self.df[:train_datetime] -> 2020-02-12 00:00:00
# current_datetime -> 2020-02-13 00:00:00
# pred -> 2020-02-13    10236.949454
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-13 00:00:00
# self.df[:train_datetime] -> 2020-02-13 00:00:00
# current_datetime -> 2020-02-14 00:00:00
# pred -> 2020-02-14    10424.094293
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-14 00:00:00
# self.df[:train_datetime] -> 2020-02-14 00:00:00
# current_datetime -> 2020-02-15 00:00:00
# pred -> 2020-02-15    9857.254753
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-15 00:00:00
# self.df[:train_datetime] -> 2020-02-15 00:00:00
# current_datetime -> 2020-02-16 00:00:00
# pred -> 2020-02-16    9978.823341
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-16 00:00:00
# self.df[:train_datetime] -> 2020-02-16 00:00:00
# current_datetime -> 2020-02-17 00:00:00
# pred -> 2020-02-17    9715.400951
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-17 00:00:00
# self.df[:train_datetime] -> 2020-02-17 00:00:00
# current_datetime -> 2020-02-18 00:00:00
# pred -> 2020-02-18    10151.148014
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-18 00:00:00
# self.df[:train_datetime] -> 2020-02-18 00:00:00
# current_datetime -> 2020-02-19 00:00:00
# pred -> 2020-02-19    9658.748801
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-19 00:00:00
# self.df[:train_datetime] -> 2020-02-19 00:00:00
# current_datetime -> 2020-02-20 00:00:00
# pred -> 2020-02-20    9544.070076
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-20 00:00:00
# self.df[:train_datetime] -> 2020-02-20 00:00:00
# current_datetime -> 2020-02-21 00:00:00
# pred -> 2020-02-21    9771.971126
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-21 00:00:00
# self.df[:train_datetime] -> 2020-02-21 00:00:00
# current_datetime -> 2020-02-22 00:00:00
# pred -> 2020-02-22    9622.517539
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-22 00:00:00
# self.df[:train_datetime] -> 2020-02-22 00:00:00
# current_datetime -> 2020-02-23 00:00:00
# pred -> 2020-02-23    10059.929283
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-23 00:00:00
# self.df[:train_datetime] -> 2020-02-23 00:00:00
# current_datetime -> 2020-02-24 00:00:00
# pred -> 2020-02-24    9591.807071
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-24 00:00:00
# self.df[:train_datetime] -> 2020-02-24 00:00:00
# current_datetime -> 2020-02-25 00:00:00
# pred -> 2020-02-25    9338.213557
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-25 00:00:00
# self.df[:train_datetime] -> 2020-02-25 00:00:00
# current_datetime -> 2020-02-26 00:00:00
# pred -> 2020-02-26    8804.50073
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-26 00:00:00
# self.df[:train_datetime] -> 2020-02-26 00:00:00
# current_datetime -> 2020-02-27 00:00:00
# pred -> 2020-02-27    8780.263576
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-27 00:00:00
# self.df[:train_datetime] -> 2020-02-27 00:00:00
# current_datetime -> 2020-02-28 00:00:00
# pred -> 2020-02-28    8744.64333
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-28 00:00:00
# self.df[:train_datetime] -> 2020-02-28 00:00:00
# current_datetime -> 2020-02-29 00:00:00
# pred -> 2020-02-29    8481.731129
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-02-29 00:00:00
# self.df[:train_datetime] -> 2020-02-29 00:00:00
# current_datetime -> 2020-03-01 00:00:00
# pred -> 2020-03-01    8541.903312
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-01 00:00:00
# self.df[:train_datetime] -> 2020-03-01 00:00:00
# current_datetime -> 2020-03-02 00:00:00
# pred -> 2020-03-02    8889.369484
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-02 00:00:00
# self.df[:train_datetime] -> 2020-03-02 00:00:00
# current_datetime -> 2020-03-03 00:00:00
# pred -> 2020-03-03    8798.615312
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-03 00:00:00
# self.df[:train_datetime] -> 2020-03-03 00:00:00
# current_datetime -> 2020-03-04 00:00:00
# pred -> 2020-03-04    8742.022
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-04 00:00:00
# self.df[:train_datetime] -> 2020-03-04 00:00:00
# current_datetime -> 2020-03-05 00:00:00
# pred -> 2020-03-05    9066.632055
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-05 00:00:00
# self.df[:train_datetime] -> 2020-03-05 00:00:00
# current_datetime -> 2020-03-06 00:00:00
# pred -> 2020-03-06    9153.424151
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-06 00:00:00
# self.df[:train_datetime] -> 2020-03-06 00:00:00
# current_datetime -> 2020-03-07 00:00:00
# pred -> 2020-03-07    8945.787844
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-07 00:00:00
# self.df[:train_datetime] -> 2020-03-07 00:00:00
# current_datetime -> 2020-03-08 00:00:00
# pred -> 2020-03-08    8006.712172
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-08 00:00:00
# self.df[:train_datetime] -> 2020-03-08 00:00:00
# current_datetime -> 2020-03-09 00:00:00
# pred -> 2020-03-09    7923.450553
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-09 00:00:00
# self.df[:train_datetime] -> 2020-03-09 00:00:00
# current_datetime -> 2020-03-10 00:00:00
# pred -> 2020-03-10    7917.364715
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-10 00:00:00
# self.df[:train_datetime] -> 2020-03-10 00:00:00
# current_datetime -> 2020-03-11 00:00:00
# pred -> 2020-03-11    7918.33323
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-11 00:00:00
# self.df[:train_datetime] -> 2020-03-11 00:00:00
# current_datetime -> 2020-03-12 00:00:00
# pred -> 2020-03-12    4840.059815
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-12 00:00:00
# self.df[:train_datetime] -> 2020-03-12 00:00:00
# current_datetime -> 2020-03-13 00:00:00
# pred -> 2020-03-13    5532.595929
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-13 00:00:00
# self.df[:train_datetime] -> 2020-03-13 00:00:00
# current_datetime -> 2020-03-14 00:00:00
# pred -> 2020-03-14    5266.264033
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-14 00:00:00
# self.df[:train_datetime] -> 2020-03-14 00:00:00
# current_datetime -> 2020-03-15 00:00:00
# pred -> 2020-03-15    5261.367338
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-15 00:00:00
# self.df[:train_datetime] -> 2020-03-15 00:00:00
# current_datetime -> 2020-03-16 00:00:00
# pred -> 2020-03-16    5123.774459
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-16 00:00:00
# self.df[:train_datetime] -> 2020-03-16 00:00:00
# current_datetime -> 2020-03-17 00:00:00
# pred -> 2020-03-17    5031.584268
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-17 00:00:00
# self.df[:train_datetime] -> 2020-03-17 00:00:00
# current_datetime -> 2020-03-18 00:00:00
# pred -> 2020-03-18    5672.803334
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-18 00:00:00
# self.df[:train_datetime] -> 2020-03-18 00:00:00
# current_datetime -> 2020-03-19 00:00:00
# pred -> 2020-03-19    6131.862709
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-19 00:00:00
# self.df[:train_datetime] -> 2020-03-19 00:00:00
# current_datetime -> 2020-03-20 00:00:00
# pred -> 2020-03-20    6178.087227
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-20 00:00:00
# self.df[:train_datetime] -> 2020-03-20 00:00:00
# current_datetime -> 2020-03-21 00:00:00
# pred -> 2020-03-21    6186.95554
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-21 00:00:00
# self.df[:train_datetime] -> 2020-03-21 00:00:00
# current_datetime -> 2020-03-22 00:00:00
# pred -> 2020-03-22    5886.980497
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-22 00:00:00
# self.df[:train_datetime] -> 2020-03-22 00:00:00
# current_datetime -> 2020-03-23 00:00:00
# pred -> 2020-03-23    6497.4267
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-23 00:00:00
# self.df[:train_datetime] -> 2020-03-23 00:00:00
# current_datetime -> 2020-03-24 00:00:00
# pred -> 2020-03-24    6811.119331
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-24 00:00:00
# self.df[:train_datetime] -> 2020-03-24 00:00:00
# current_datetime -> 2020-03-25 00:00:00
# pred -> 2020-03-25    6661.131408
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-25 00:00:00
# self.df[:train_datetime] -> 2020-03-25 00:00:00
# current_datetime -> 2020-03-26 00:00:00
# pred -> 2020-03-26    6728.128453
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-26 00:00:00
# self.df[:train_datetime] -> 2020-03-26 00:00:00
# current_datetime -> 2020-03-27 00:00:00
# pred -> 2020-03-27    6366.582651
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-27 00:00:00
# self.df[:train_datetime] -> 2020-03-27 00:00:00
# current_datetime -> 2020-03-28 00:00:00
# pred -> 2020-03-28    6330.631858
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-28 00:00:00
# self.df[:train_datetime] -> 2020-03-28 00:00:00
# current_datetime -> 2020-03-29 00:00:00
# pred -> 2020-03-29    5884.942287
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-29 00:00:00
# self.df[:train_datetime] -> 2020-03-29 00:00:00
# current_datetime -> 2020-03-30 00:00:00
# pred -> 2020-03-30    6364.515239
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-30 00:00:00
# self.df[:train_datetime] -> 2020-03-30 00:00:00
# current_datetime -> 2020-03-31 00:00:00
# pred -> 2020-03-31    6436.670993
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-03-31 00:00:00
# self.df[:train_datetime] -> 2020-03-31 00:00:00
# current_datetime -> 2020-04-01 00:00:00
# pred -> 2020-04-01    6647.490815
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-04-01 00:00:00
# self.df[:train_datetime] -> 2020-04-01 00:00:00
# current_datetime -> 2020-04-02 00:00:00
# pred -> 2020-04-02    6819.851275
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-04-02 00:00:00
# self.df[:train_datetime] -> 2020-04-02 00:00:00
# current_datetime -> 2020-04-03 00:00:00
# pred -> 2020-04-03    6727.618786
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-04-03 00:00:00
# self.df[:train_datetime] -> 2020-04-03 00:00:00
# current_datetime -> 2020-04-04 00:00:00
# pred -> 2020-04-04    6932.665576
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-04-04 00:00:00
# self.df[:train_datetime] -> 2020-04-04 00:00:00
# current_datetime -> 2020-04-05 00:00:00
# pred -> 2020-04-05    6759.353887
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-04-05 00:00:00
# self.df[:train_datetime] -> 2020-04-05 00:00:00
# current_datetime -> 2020-04-06 00:00:00
# pred -> 2020-04-06    7338.857039
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-04-06 00:00:00
# self.df[:train_datetime] -> 2020-04-06 00:00:00
# current_datetime -> 2020-04-07 00:00:00
# pred -> 2020-04-07    7207.405464
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-04-07 00:00:00
# self.df[:train_datetime] -> 2020-04-07 00:00:00
# current_datetime -> 2020-04-08 00:00:00
# pred -> 2020-04-08    7361.57439
# Freq: D, dtype: float64
# ---
# train_datetime -> 2020-04-08 00:00:00
# self.df[:train_datetime] -> 2020-04-08 00:00:00
# current_datetime -> 2020-04-09 00:00:00
# pred -> 2020-04-09    7338.191745
# Freq: D, dtype: float64
# ---
# mae 41.6731 mape 0.476 mse 4177.262 rmse 64.6317 rmspe 0.7696 r2 0.9982 pearson 0.9991

# %%
# AR 1d
# AIC 18628.20857982622 best_params {'p_order': 9, 'd_order': 1, 'q_order': 0}
# mae 41.6731 mape 0.476 mse 4177.262 rmse 64.6317 rmspe 0.7696 r2 0.9982 pearson 0.9991

# %%
# AR 1h
# AIC 354611.7078715251 best_params {'p_order': 9, 'd_order': 1, 'q_order': 0}
# mae 3.597 mape 0.0411 mse 38.1941 rmse 6.1801 rmspe 0.073 r2 1.0 pearson 1.0

# %%
# df_train.tail()
df_test.head()
# df_train.to_csv('train_ar_1d.csv', sep = "\t", index = False)
# df_test.to_csv('test_ar_1d.csv', sep = "\t", index = False)
# pd.read_csv('train_ar_1d.csv', sep = "\t")
# pd.read_csv('test_ar_1d.csv', sep = "\t")
# df_train.to_csv('train_ar_1h.csv', sep = "\t", index = False)
# df_test.to_csv('test_ar_1h.csv', sep = "\t", index = False)
# pd.read_csv('train_ar_1h.csv', sep = "\t")
# pd.read_csv('test_ar_1h.csv', sep = "\t")
# Out:
#             date_test   y_test  y_test_predict
# 0 2019-05-16 03:00:00  8247.34     8249.870975
# 1 2019-05-16 04:00:00  7983.68     8000.544936
# 2 2019-05-16 05:00:00  7994.15     8009.381083
# 3 2019-05-16 06:00:00  8126.34     8125.339677
# 4 2019-05-16 07:00:00  8010.72     8013.253731

# %%
fig, ax = plt.subplots(figsize=(18, 10))

# ax.plot(df_train['date_train'], df_train['y_train'], label = 'train', color="blue")
# ax.plot(df_train['date_train'], df_train['y_train_predict'], '--', label = 'train predict', color="red")

ax.plot(df_test['date_test'], df_test['y_test'], label = 'test', color="blue")
ax.plot(df_test['date_test'], df_test['y_test_predict'], '--', label = 'test predict', color="red")

ax.legend()
plt.show()

# %%
a = [2, 4, 16, 32, 64, 128, 256]
data = { 'a': a}
df_a = pd.DataFrame(data)
df_a['diff_1'] = df_a['a'].diff()
df_a['diff_2'] = df_a['diff_1'].diff()
df_a[:5]
# Out:
#     a  diff_1  diff_2
# 0   2     NaN     NaN
# 1   4     2.0     NaN
# 2  16    12.0    10.0
# 3  32    16.0     4.0
# 4  64    32.0    16.0

# %%
last_close_price = df_a[:5]['a'].values[-1]
before_last_close_price = df_a[:5]['a'].values[-2]
last_close_diff_price = last_close_price - before_last_close_price
pred = last_close_price + last_close_diff_price + df_a[:6]['diff_2'].values[-1]
pred
# Out:
# 128.0

# %%
df = df_gemini_price_d.copy()
df = df.set_index('Date')
df = df.sort_values(by = ['Date'])
df = df.loc[:, ['Close']]

df = df.asfreq('D') # D or H

model = ARIMA(df[:'2019-04-30'], order=(1, 1, 0))
# print(df[:'2019-04-29'].index[-1])
print(df[:'2019-04-30'].index[-1])
fit_model = model.fit()

pred = fit_model.predict(start = '2019-04-30', end = '2019-04-30', dynamic = False)
pred
# Out:
# 2019-04-30 00:00:00
# Date
# 2019-04-30    3.370656
# Freq: D, dtype: float64
